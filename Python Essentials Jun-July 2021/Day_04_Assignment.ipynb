# %% [markdown]
# ## Landing Plane

# %%
altitude = int(input("Enter Altitude: "))
if altitude <= 1000:
    print("Safe to land")
elif altitude <= 5000:
    print("Bring down to 1000")
else:
    print("Go around & try later")
# Out:
# Enter Altitude: 6500
# Go around & try later
