# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Questions 1
#
# ## Find the value of the following questions, Where x=5

# %%
x=5

# %% [markdown]
# ### ● (2x+5/x^2+5x+6)

# %%
print(2*x+5/x**2+5*x+6)
# Out:
# 41.2

# %% [markdown]
# ### ● (x^2+5x+6/2x+5)

# %%
print(x**2+5*x+6/2*x+5)
# Out:
# 70.0

# %% [markdown]
# ### ● (2x-3)(x-9)

# %%
print((2*x-3)*(x-9))
# Out:
# -28

# %% [markdown]
# ## Questions 2
# ## Create a username and password login file using nested while loop

# %%
#login with username: INDIA & password: IND

uname,pswd=None,None

while pswd!='IND':
    while uname!='INDIA':
        uname=input('Enter Username: ')
        pswd=input('Enter Password: ')
        if uname!='INDIA':
            print('Invalid Username\n')
    if pswd!='IND':
        print('Invalid Password\n')
        pswd=input('Enter Password: ')
    
print('Login Successfull')
# Out:
# Enter Username: india
# Enter Password: ind
# Invalid Username
#
# Enter Username: Indias
# Enter Password: IND
# Invalid Username
#
# Enter Username: INDIA
# Enter Password: ind
# Invalid Password
#
# Enter Password: IND
# Login Successfull
