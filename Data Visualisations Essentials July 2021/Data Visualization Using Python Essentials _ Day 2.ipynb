# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(0, 100, size = (10, 4)), columns = ['a', 'b', 'c', 'd'])
df
# Out:
#     a   b   c   d
# 0  64  99  71  78
# 1   6  13   6  38
# 2  54  40  25  42
# 3  55  45  88  77
# 4  34  53  46  74
# 5  71  19  40  55
# 6  32  66  95  66
# 7  14  34   2  65
# 8  46  46  94  71
# 9  99  51  96  15

# %%
df.plot(kind = 'bar', figsize = (20, 5), color = ['red', 'green', 'blue','gray'])
plt.title("Bar Graph")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
plt.bar(df.index, df.a, color = 'Red')
plt.title("Bar Graph of a")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
plt.bar(df.index, df.b, color = 'Blue')
plt.title("Bar Graph of b")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
plt.bar(df.index, df.a, color = 'Green')
plt.title("Bar Graph of c")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
plt.bar(df.index, df.a, color = 'Gray')
plt.title("Bar Graph of d")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()
