# %% [markdown]
# # Day 4

# %%
import numpy as np

# %% [markdown]
# ## Answer 1

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ## Answer 2

# %%
arr = np.random.randint(0,10,5)
arr
# Out:
# array([6, 0, 6, 6, 7])

# %%
s = pd.Series(arr)
s
# Out:
# 0    6
# 1    0
# 2    6
# 3    6
# 4    7
# dtype: int64

# %% [markdown]
# ## Answer 3

# %%
list(s.index)
# Out:
# [0, 1, 2, 3, 4]

# %%
s.index = [1,10,100,1001,10101]
s
# Out:
# 1        6
# 10       0
# 100      6
# 1001     6
# 10101    7
# dtype: int64

# %%
s.index
# Out:
# Int64Index([1, 10, 100, 1001, 10101], dtype='int64')

# %%
df = pd.DataFrame([[1,1,1,1,1],[2,22,20,10,22],[3,333,300,100,303],[4,44,4000,1000,4004],[5,55,50000,10000,50505]])
df
# Out:
#    0    1      2      3      4
# 0  1    1      1      1      1
# 1  2   22     20     10     22
# 2  3  333    300    100    303
# 3  4   44   4000   1000   4004
# 4  5   55  50000  10000  50505

# %%
list(df.columns)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# #### Converting the index of a series into a column of a dataframe

# %%
df.columns = s.index
df
# Out:
#    1      10     100    1001   10101
# 0      1      1      1      1      1
# 1      2     22     20     10     22
# 2      3    333    300    100    303
# 3      4     44   4000   1000   4004
# 4      5     55  50000  10000  50505

# %% [markdown]
# ## Answer 4

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
mpg = sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Answer 5

# %%
mpg.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %% [markdown]
# ## Answer 6

# %%
usa_mpg = mpg[mpg.origin == 'usa']
usa_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
